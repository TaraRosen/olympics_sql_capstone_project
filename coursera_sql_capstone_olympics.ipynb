# %%
import pandas as pd

import sqlite3

# %%
#pd.set_option('display.max_rows', 60000)

# %%
events_df = pd.read_csv('athlete_events.csv')
regions_df = pd.read_csv('noc_regions.csv')

# %%
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
regions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
# NOC       230 non-null object
# region    227 non-null object
# notes     21 non-null object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
events_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
regions_df.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
# connect to database
conn = sqlite3.connect(':memory:')

# create cursor
cur = conn.cursor()

# %%
events_df.to_sql('events', con = conn, index=False)
regions_df.to_sql('regions', con = conn, index=False)

# %%
cur.execute("""SELECT * 
               FROM events
            """)
events = pd.DataFrame(cur.fetchall())                    # create dataframe from sql query
events.columns = [x[0] for x in cur.description]         # labels dataframe columns
events                                                   # view dataframe
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
print(events.Year.min())
print(events.Year.max())
# Out:
# 1896
# 2016

# %%
events.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
events['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
cur.execute("""SELECT DISTINCT(Year) AS Rugby_Sevens
               FROM events
               WHERE Sport = 'Rugby Sevens' 
               ORDER By Year""")
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#    Rugby_Sevens
# 0          2016

# %%
cur.execute("""SELECT DISTINCT(Year) AS Roque
               FROM events
               WHERE Sport = 'Roque' 
               ORDER By Year""")
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#    Roque
# 0   1904

# %%
cur.execute("""SELECT DISTINCT(Year) AS Motorboating
               FROM events
               WHERE Sport = 'Motorboating' 
               ORDER By Year""")
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#    Motorboating
# 0          1908

# %%
cur.execute("""SELECT DISTINCT(Year) AS Jeu_De_Paume
               FROM events
               WHERE Sport = 'Jeu De Paume' 
               ORDER By Year""")
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#    Jeu_De_Paume
# 0          1908

# %%
cur.execute("""SELECT DISTINCT(Year) AS Military_Ski_Patrol
               FROM events
               WHERE Sport = 'Military Ski Patrol' 
               ORDER By Year""")
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#    Military_Ski_Patrol
# 0                 1924

# %%
cur.execute("""SELECT DISTINCT(Year) AS Art_Competitions
               FROM events
               WHERE Sport = 'Art Competitions'
               ORDER BY Year""")
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#    Art_Competitions
# 0              1912
# 1              1920
# 2              1924
# 3              1928
# 4              1932
# 5              1936
# 6              1948

# %%
cur.execute("""SELECT DISTINCT(Year) AS Tug_Of_War
               FROM events
               WHERE Sport = 'Tug-Of-War'
               ORDER BY Year""")
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#    Tug_Of_War
# 0        1900
# 1        1904
# 2        1906
# 3        1908
# 4        1912
# 5        1920

# %%
cur.execute("""SELECT DISTINCT(Year) AS Athletics
               FROM events
               WHERE Sport = 'Athletics'
               ORDER BY Year
            """)
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#     Athletics
# 0        1896
# 1        1900
# 2        1904
# 3        1906
# 4        1908
# 5        1912
# 6        1920
# 7        1924
# 8        1928
# 9        1932
# 10       1936
# 11       1948
# 12       1952
# 13       1956
# 14       1960
# 15       1964
# 16       1968
# 17       1972
# 18       1976
# 19       1980
# 20       1984
# 21       1988
# 22       1992
# 23       1996
# 24       2000
# 25       2004
# 26       2008
# 27       2012
# 28       2016

# %%
cur.execute("""SELECT *
               FROM events
               WHERE Sport = 'Athletics'
               ORDER BY Year
            """)
athletics = pd.DataFrame(cur.fetchall())
athletics.columns = [x[0] for x in cur.description]
athletics.head()
# Out:
#       ID                       Name Sex   Age  Height  Weight           Team  \
# 0   4113         Anastasios Andreou   M   NaN     NaN     NaN         Greece
# 1   9760           Spyridon Belokas   M   NaN     NaN     NaN         Greece
# 2  12068       Arthur Charles Blake   M  24.0     NaN     NaN  United States
# 3  12068       Arthur Charles Blake   M  24.0     NaN     NaN  United States
# 4  16616  Thomas Edmund "Tom" Burke   M  21.0   183.0    66.0  United States
#
#    NOC        Games  Year  Season    City      Sport  \
# 0  GRE  1896 Summer  1896  Summer  Athina  Athletics
# 1  GRE  1896 Summer  1896  Summer  Athina  Athletics
# 2  USA  1896 Summer  1896  Summer  Athina  Athletics
# 3  USA  1896 Summer  1896  Summer  Athina  Athletics
# 4  USA  1896 Summer  1896  Summer  Athina  Athletics
#
#                                 Event   Medal
# 0  Athletics Men's 110 metres Hurdles    None
# 1            Athletics Men's Marathon    None
# ...

# %%
cur.execute("""SELECT DISTINCT(Year) AS Trampolining
               FROM events
               WHERE Sport = 'Trampolining'
               ORDER BY Year
            """)
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#    Trampolining
# 0          2000
# 1          2004
# 2          2008
# 3          2012
# 4          2016

# %%
cur.execute("""SELECT DISTINCT(Year) AS Basketball
               FROM events
               WHERE Sport = 'Basketball'
               ORDER BY Year
            """)
active_years = pd.DataFrame(cur.fetchall())
active_years.columns = [x[0] for x in cur.description]
active_years
# Out:
#     Basketball
# 0         1936
# 1         1948
# 2         1952
# 3         1956
# 4         1960
# 5         1964
# 6         1968
# 7         1972
# 8         1976
# 9         1980
# 10        1984
# 11        1988
# 12        1992
# 13        1996
# 14        2000
# 15        2004
# 16        2008
# 17        2012
# 18        2016

# %%
events['Season'].unique()
# Out:
# array(['Summer', 'Winter'], dtype=object)

# %%
cur.execute("""SELECT * 
               FROM events
               WHERE Season = 'Summer'
               ORDER BY Year
            """)
summer = pd.DataFrame(cur.fetchall())
summer.columns = [x[0] for x in cur.description]
summer
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0         1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
# 1         1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
# 2         1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
# 3         1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
# 4         4113                  Anastasios Andreou   M   NaN     NaN     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 222547  135528                       Marc Zwiebler   M  32.0   181.0    75.0
# 222548  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 222549  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 222550  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 222551  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
summer.to_csv(r'summer_games.csv')

# %%
cur.execute("""SELECT * 
               FROM events
               WHERE Season = 'Winter'
               ORDER BY Year""")
winter = pd.DataFrame(cur.fetchall())
winter.columns = [x[0] for x in cur.description]
winter
# Out:
#            ID                    Name Sex   Age  Height  Weight  \
# 0         391      Clarence John Abel   M  23.0   185.0   102.0
# 1         992             Josef Adolf   M  25.0     NaN     NaN
# 2        1077     Xavier Affentranger   M  26.0     NaN     NaN
# 3        1077     Xavier Affentranger   M  26.0     NaN     NaN
# 4        1077     Xavier Affentranger   M  26.0     NaN     NaN
# ...       ...                     ...  ..   ...     ...     ...
# 48559  135485  Stepan Olegovich Zuyev   M  25.0   189.0    90.0
# 48560  135500      Kristaps Zvejnieks   M  21.0   185.0    87.0
# 48561  135500      Kristaps Zvejnieks   M  21.0   185.0    87.0
# 48562  135570                Piotr ya   M  27.0   176.0    59.0
# 48563  135570                Piotr ya   M  27.0   176.0    59.0
#
#                  Team  NOC        Games  Year  Season      City  \
# 0       United States  USA  1924 Winter  1924  Winter  Chamonix
# 1      Czechoslovakia  TCH  1924 Winter  1924  Winter  Chamonix
# ...

# %%
winter.drop(['Height', 'Weight', 'Team', 'Games'], axis = 1, inplace = True)

# %%
winter.head()
# Out:
#      ID                 Name Sex   Age  NOC  Year  Season      City  \
# 0   391   Clarence John Abel   M  23.0  USA  1924  Winter  Chamonix
# 1   992          Josef Adolf   M  25.0  TCH  1924  Winter  Chamonix
# 2  1077  Xavier Affentranger   M  26.0  SUI  1924  Winter  Chamonix
# 3  1077  Xavier Affentranger   M  26.0  SUI  1924  Winter  Chamonix
# 4  1077  Xavier Affentranger   M  26.0  SUI  1924  Winter  Chamonix
#
#                   Sport                                      Event   Medal
# 0            Ice Hockey                Ice Hockey Men's Ice Hockey  Silver
# 1       Nordic Combined           Nordic Combined Men's Individual    None
# 2           Ski Jumping  Ski Jumping Men's Normal Hill, Individual    None
# 3  Cross Country Skiing   Cross Country Skiing Men's 18 kilometres    None
# 4       Nordic Combined           Nordic Combined Men's Individual    None

# %%
winter.to_csv(r'winter_games.csv', index=True, index_label = 'Unique_ID')

# %%
winter = pd.read_csv('winter_games.csv', )

# %%
winter.head()
# Out:
#    Unique_ID    ID                 Name Sex   Age  NOC  Year  Season  \
# 0          0   391   Clarence John Abel   M  23.0  USA  1924  Winter
# 1          1   992          Josef Adolf   M  25.0  TCH  1924  Winter
# 2          2  1077  Xavier Affentranger   M  26.0  SUI  1924  Winter
# 3          3  1077  Xavier Affentranger   M  26.0  SUI  1924  Winter
# 4          4  1077  Xavier Affentranger   M  26.0  SUI  1924  Winter
#
#        City                 Sport                                      Event  \
# 0  Chamonix            Ice Hockey                Ice Hockey Men's Ice Hockey
# 1  Chamonix       Nordic Combined           Nordic Combined Men's Individual
# 2  Chamonix           Ski Jumping  Ski Jumping Men's Normal Hill, Individual
# 3  Chamonix  Cross Country Skiing   Cross Country Skiing Men's 18 kilometres
# 4  Chamonix       Nordic Combined           Nordic Combined Men's Individual
#
#     Medal
# 0  Silver
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
winter['Medal'].unique()
# Out:
# array(['Silver', nan, 'Bronze', 'Gold'], dtype=object)

# %%
winter['NOC'].unique()
# Out:
# array(['USA', 'TCH', 'SUI', 'SWE', 'FRA', 'GBR', 'ITA', 'AUT', 'NOR',
#        'FIN', 'POL', 'NEP', 'CAN', 'BEL', 'HUN', 'AUS', 'YUG', 'LAT',
#        'IND', 'JPN', 'GER', 'ROU', 'LTU', 'EST', 'MEX', 'ARG', 'NED',
#        'LUX', 'BUL', 'TUR', 'LIE', 'ESP', 'GRE', 'ISL', 'KOR', 'DEN',
#        'CHI', 'LIB', 'NZL', 'POR', 'IRI', 'URS', 'BOL', 'RSA', 'PRK',
#        'MGL', 'MAR', 'FRG', 'GDR', 'TPE', 'PHI', 'AND', 'SMR', 'CYP',
#        'CHN', 'CRC', 'EGY', 'IVB', 'SEN', 'MON', 'PUR', 'ISV', 'GUM',
#        'GUA', 'AHO', 'JAM', 'FIJ', 'EUN', 'BRA', 'SLO', 'ALG', 'CRO',
#        'SWZ', 'IRL', 'HON', 'BER', 'GEO', 'RUS', 'CZE', 'ARM', 'BIH',
#        'SVK', 'UKR', 'KAZ', 'UZB', 'BLR', 'MDA', 'TTO', 'ASA', 'KGZ',
#        'ISR', 'AZE', 'VEN', 'KEN', 'MKD', 'SCG', 'URU', 'TJK', 'CMR',
#        'THA', 'HKG', 'MAD', 'ETH', 'ALB', 'PAK', 'PER', 'COL', 'SRB',
#        'MNE', 'GHA', 'CAY', 'TOG', 'TGA', 'DMA', 'TLS', 'IOA', 'PAR',
#        'MLT', 'ZIM'], dtype=object)

# %%
winter.to_sql('winter', con = conn, index=False)

# %%
cur.execute("""SELECT DISTINCT(Event), NOC, COUNT(Medal), Year
               FROM winter
               WHERE Medal = 'Gold'
               GROUP BY NOC, Year
               ORDER BY 4, 3
               """)
gold = pd.DataFrame(cur.fetchall())
gold.columns = [x[0] for x in cur.description]
gold

# %%
cur.execute("""SELECT DISTINCT(Event)
               FROM winter
               WHERE Medal = 'Gold' AND NOC = 'CAN' AND Year = '2014'
               ORDER BY 1
            """)
gold = pd.DataFrame(cur.fetchall())
gold.columns = [x[0] for x in cur.description]
gold
